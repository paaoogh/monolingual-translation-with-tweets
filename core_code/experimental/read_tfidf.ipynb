# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

import nltk 
nltk.download('stopwords')  
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /Users/paogh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
mujeres = pd.read_csv("tweets_mujeres.csv",index_col="Unnamed: 0")["tweet"]

# %%
stops = stopwords.words("spanish")

# %%
vectorizer = TfidfVectorizer(max_features = 20000, min_df=25, stop_words=stopwords.words('spanish'))  
X = vectorizer.fit_transform(mujeres).toarray()

# %%
X.shape #tenemos más de un millón de palabras originalmente
# Out:
# (201038, 123066)

# %%
X.shape #tenemos 7133 palabras <3
# Out:
# (201038, 7133)

# %%
palabras = vectorizer.get_feature_names()

# %%
len(palabras)
# Out:
# 7133

# %%
len(stops)
# Out:
# 313

# %%
palabras
# Out:
# ['00',
#  '000',
#  '09',
#  '10',
#  '100',
#  '1000',
#  '11',
#  '12',
#  '120',
#  '13',
#  '130',
#  '14',
#  '140',
#  '15',
#  '150',
#  '15deseptiembre',
#  '16',
#  '17',
#  '175',
#  '18',
#  '19',
#  '1985',
#  '1990',
#  '19s',
#  '20',
#  '200',
#  '2000',
#  '2006',
#  '2008',
#  '2013',
#  '2014',
#  '2017',
#  '2018',
#  '2021',
#  '2022',
#  '2023',
#  '2024',
#  '2028',
#  '2030',
#  '21',
#  '22',
#  '23',
#  '24',
#  '25',
#  '26',
#  '27',
#  '28',
#  '30',
#  '300',
#  '35',
#  '40',
#  '43',
#  '46',
#  '4a',
#  '4t',
#  '4ta',
#  '50',
#  '500',
#  '60',
#  '61',
#  '68',
#  '70',
#  '80',
#  '90',
#  '911',
#  '95',
#  '99',
#  '_brendaespinoza',
#  '_marthaguerrero',
#  '_vicenteserrano',
#  'a_gurria',
#  'a_montielr',
#  'aaah',
#  'aatayder',
#  'abajo',
#  'abandonadas',
#  'abandono',
#  'abasto',
#  'abc',
#  'abelinalopezr',
#  'aberración',
#  'aberrante',
#  'abierta',
#  'abierto',
#  'abiertos',
#  'abortado',
#  'aborto',
#  'abra',
# ...
