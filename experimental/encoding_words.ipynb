# %%
import torch
import gc
import transformers
import pandas as pd
from datasets import Dataset
from transformers import BertTokenizer, BertConfig
from transformers import BertForPreTraining, BertForMaskedLM

# %%
mujeres = pd.read_csv("gobernadoras_small.csv",usecols=['id','tweet'])

# %%
hombres = pd.read_csv("gobernadores_small.csv",usecols=['id','tweet'])

# %%
hombres.index
# Out:
# RangeIndex(start=0, stop=37962, step=1)

# %%
import numpy as np

np.random.seed(10)

remove_n = len(mujeres) - len(hombres)
drop_indices = np.random.choice(mujeres.index, remove_n, replace=False)
mujeres = mujeres.drop(drop_indices)

# %%
beto = 'dccuchile/bert-base-spanish-wwm-cased'

tokenizer = BertTokenizer.from_pretrained(beto, 
                        return_offset_mapping=True)
model = BertForMaskedLM.from_pretrained(beto, return_dict=True)

# %%
len(hombres),len(mujeres)
# Out:
# (37962, 37962)

# %%
tokenizer
# Out:
# PreTrainedTokenizer(name_or_path='dccuchile/bert-base-spanish-wwm-cased', vocab_size=31002, model_max_len=512, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %%
def preprocess_function(examples):
    inputs = [ex for ex in examples["mujeres_tweet"]]
    targets = [ex for ex in examples["hombres_tweet"]]

    model_inputs = tokenizer(inputs,
                        text_pair=targets,
                        padding="max_length", 
                        truncation=True,
                        max_length=280,
                        return_tensors='pt'
                        )
    return model_inputs

# %%
def tokenize_sentences(hombres, mujeres):
    data = {"mujeres_tweet":list(mujeres.tweet),
        "hombres_tweet":list(hombres.tweet)}
    raw_dataset = pd.DataFrame(data)

    ds = Dataset.from_pandas(raw_dataset,preserve_index=True)
    ds = ds.rename_column('__index_level_0__','id')
    ds = ds.train_test_split(shuffle = True, seed = 200, test_size=0.2)

    train_set = preprocess_function(ds["train"])
    test_set = preprocess_function(ds["test"])
    
    train_set['labels'] = train_set['input_ids'].detach().clone()
    test_set['labels'] = test_set['input_ids'].detach().clone()
    
    return train_set, test_set

# %%
trainingSet, testSet= tokenize_sentences(hombres, mujeres)

# %%
#random_tensor = torch.rand(trainingSet['input_ids'].shape)
#masked_tensor = (random_tensor < 0.15)*(trainingSet['input_ids'] != 101)*(trainingSet['input_ids'] != 102)*(trainingSet['input_ids'] != 0)

# %%
# getting all those indices from each row which are set to True, i.e. masked.
#nonzeros_indices = []
#for i in range(len(masked_tensor)):
    #nonzeros_indices.append(torch.flatten(masked_tensor[i].nonzero()).tolist())

# %%
# setting the values at those indices to be a MASK token (103) for every row in the original input_ids.
#for i in range(len(trainingSet['input_ids'])):
#    trainingSet['input_ids'][i, nonzeros_indices[i]] = 103

# %%
input_ids = trainingSet["input_ids"]
input_ids[0][7] = tokenizer.mask_token_id

labels = trainingSet["input_ids"].clone()
labels[labels!= tokenizer.mask_token_id] = -100

# %%
class TweetsDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    
    def __len__(self):
        return len(self.encodings['input_ids'])

    def __getitem__(self, index):
        input_ids = self.encodings['input_ids'][index]
        labels = self.encodings['labels'][index]
        attention_mask = self.encodings['attention_mask'][index]
        token_type_ids = self.encodings['token_type_ids'][index]
        return {
            'input_ids': input_ids,
            'labels': labels,
            'attention_mask': attention_mask,
            'token_type_ids': token_type_ids
        }

# %%
dataset = TweetsDataset(trainingSet)

# %%
input_ids = testSet["input_ids"]
input_ids[0][7] = tokenizer.mask_token_id

labels = testSet["input_ids"].clone()
labels[labels!= tokenizer.mask_token_id] = -100

# %%
class TweetsDataset2(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    
    def __len__(self):
        return len(self.encodings['input_ids'])

    def __getitem__(self, index):
        input_ids = self.encodings['input_ids'][index]
        labels = self.encodings['labels'][index]
        attention_mask = self.encodings['attention_mask'][index]
        token_type_ids = self.encodings['token_type_ids'][index]
        return {
            'input_ids': input_ids,
            'labels': labels,
            'attention_mask': attention_mask,
            'token_type_ids': token_type_ids
        }

# %%
test_dataset = TweetsDataset2(testSet)

# %%
def get_dataloader(dataset):
    dataloader = torch.utils.data.DataLoader(
      dataset,
      batch_size=32,
      shuffle=True,
    num_workers=5
    )
    return dataloader

def get_Testdataloader(test_dataset):
    dataloader = torch.utils.data.DataLoader(
      test_dataset,
      batch_size=16,
      shuffle=True,
    num_workers=5
    )
    return dataloader

# %%
Data_loader_train = get_dataloader(dataset)
Data_loader_test = get_Testdataloader(test_dataset)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
model.to(device)
# Out:
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(31002, 768, padding_idx=1)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (cls): BertOnlyMLMHead(
#     (predictions): BertLMPredictionHead(
#       (transform): BertPredictionHeadTransform(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (transform_act_fn): GELUActivation()
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (decoder): Linear(in_features=768, out_features=31002, bias=True)
#     )
#   )
# )

# %%
from tqdm.auto import tqdm
from transformers import AdamW
from transformers import DataCollatorForLanguageModeling

# %%
def corr(x,y): return np.corrcoef(x,y)[0][1]
def corr_d(eval_pred): return {'pearson': corr(*eval_pred)}

# %%
from transformers import TrainingArguments, Trainer

# %%
epochs = 2
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-5)

# %%
gc.collect()
# Out:
# 0

# %%
torch.cuda.empty_cache()

# %%
def compute_metrics(pred):
    corr = torch.corrcoef(pred)
    return corr.item()

# %%
def training(Data_loader_train):
    model.train()
    
    loop = tqdm(Data_loader_train)
    for batch in loop:
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        labels = batch['labels'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        token_type_ids = batch["token_type_ids"].to(device)
        outputs = model(input_ids=input_ids,
                        labels=labels,
                        attention_mask = attention_mask,
                        token_type_ids = token_type_ids)
        loss = outputs.loss
        x = outputs.logits
        corr = compute_metrics(x.view(-1))
        loss.backward()
        optimizer.step()

        loop.set_description("Epoch: {}".format(epoch))
        loop.set_postfix(loss=loss.item(), corr = corr)
    return outputs

def test(Data_loader_test):
    model.eval()
    loop = tqdm(Data_loader_test)
    
    for batch in loop:
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        labels = batch['labels'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        token_type_ids = batch["token_type_ids"].to(device)
        outputs = model(input_ids=input_ids,
                        labels=labels,
                        attention_mask = attention_mask,
                        token_type_ids = token_type_ids)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        x = outputs.logits
        corr = compute_metrics(x.view(-1))

        loop.set_description("Epoch: {}".format(epoch))
        loop.set_postfix(loss=loss.item(), corr=corr)
    return outputs

# %%
for epoch in range(epochs):
    gc.collect()
    torch.cuda.empty_cache()
    
    print("Training BETO")
    training(Data_loader_train)
    
    print("Collect gc")
    gc.collect()
    print("Empty cache")
    torch.cuda.empty_cache()
    print("Test phase")
    
    test(Data_loader_test)
# Out:
# Training BETO
#   0%|          | 0/950 [00:00<?, ?it/s]
# Collect gc
# Empty cache
# Test phase
#   0%|          | 0/475 [00:00<?, ?it/s]
# Training BETO
#   0%|          | 0/950 [00:00<?, ?it/s]
# Collect gc
# Empty cache
# Test phase
#   0%|          | 0/475 [00:00<?, ?it/s]

# %%
model.save_pretrained('./my_model_checkpoints/')

# %%
tokenizer.save_pretrained('./my_model_checkpoints/')
# Out:
# ('./my_model_checkpoints/tokenizer_config.json',
#  './my_model_checkpoints/special_tokens_map.json',
#  './my_model_checkpoints/vocab.txt',
#  './my_model_checkpoints/added_tokens.json')

# %%
mujeres.tweet.to_numpy()[0]
# Out:
# '@MarinadelPilar ¿estrategia?, puro hacer como que trabajan, ya parece usted la "Sheimbaum Cachanilla".'

# %%
lista = []
for i in mujeres.tweet.to_numpy():
    lista.append(i)
    
lista
# Out:
# ['@MarinadelPilar ¿estrategia?, puro hacer como que trabajan, ya parece usted la "Sheimbaum Cachanilla".',
#  '@MarinadelPilar  https://t.co/6mKV4rw4Wh',
#  '@MarinadelPilar Y lo que venga',
#  '@MarinadelPilar Y en delincuencia/crimen organizado, también … a nivel mundial!!!',
#  '@MarinadelPilar “No les vamos a fallar” dijo la ‘gobernadora’ de una de las entidades más inseguras del mundo 🤡 aplica la ley, inepta',
#  '@MarinadelPilar dándole prioridad a un parque mientras la inseguridad de la baja va en aumento, al putazo tus prioridades, para de mamar y ponte a trabajar, deja de pasearte a lo pndjo !!!',
#  '@MarinadelPilar Prioridad deberías darle a la seguridad ciudadana para que podamos salir a las calles sin temor alguno, deja tus parques para después no mms!!',
#  '@MarinadelPilar @M_OlgaSCordero ¡Feliz Cumpleaños! Para la ex ministra y senadora @M_OlgaSCordero  🎉🎊 ¡Que tengas un excelente día!',
#  '@MarinadelPilar @ManuelBartlett @CFEmx ¿Alcanzarán a concretar estos proyectos  ahora que detuvieron a Caro Quintero?',
#  '@MarinadelPilar Será nacida en México o es otra, que nació con los grin-gos?',
#  '@MarinadelPilar Ya les pagaron los viáticos? Por qué los papás pagaron el viaje, que poca madre tienes!!',
#  '¡Estamos muy orgullos de ti! Gracias por representar a Baja California con el corazón. ❤️  (2/2)',
#  '@MarinadelPilar @ManuelBartlett @CFEmx Agarras parejo tiktogober desde el colágeno hasta la leche en polvo  https://t.co/w3oSqnDoMd',
#  '@MarinadelPilar El gobierno de BC cree que los bajacalifornianos nacieron ayer.  Cree que hacer uso del dinero público para trabajar en obras para sus aplaudidores como regalitos y no como parte de su responsabilidad como gobierno. #CORRUPCION del Pilar 👸🏻💩💁🏽\u200d♂️🤦🏽\u200d♂️  https://t.co/ztwOGIUEAO',
#  '@MarinadelPilar Primero quitas el uso del cubrebocas (mala decisión, por cierto) y ahora nos pides que lo usemos. Esas decisiones no deben ser políticas, cuestan vidas!',
#  '@MarinadelPilar @ManuelBartlett @CFEmx Conectar Baja California con la Red Nacional de Electricidad sería lo ideal para la problemática de electricidad pero si, sale carisimo esa conexión. Mejor energía renovables, pero la salida rápida sería la planta nuclear si es que sigue en pie esa idea.  #CuartaTransformación',
#  '@MarinadelPilar @ManuelBartlett @CFEmx Cómo pueden salir proyectos transcendentales de Gente que Que No tiene Miras de Energías Limpias para un Mejor Futuro.Gente que se quedó Resagada en el Pasado  que trabaja con los fociles.',
#  '@MarinadelPilar @ManuelBartlett @CFEmx la cara del  Barlett, ¿Cuanto me va a tocar?',
#  '@MarinadelPilar ♥️',
#  '@MarinadelPilar @ManuelBartlett @CFEmx ¿Que se siente trabajar con uno de los dinosaurios más corruptos de la política mexicana?  Solo espero ya no haya apagones en pleno verano en Mexicali 😬',
#  '@MarinadelPilar Temperaturas altas, incendios y falta de agua en #Mexicali.    No hubo agua para sofocarlo a tiempo. Los gringos tuvieron que pasar una manguera entre los alambres del muro, solo así pudieron controlarlo.  https://t.co/LRa9AxX19x',
#  '@MarinadelPilar Ahh caray ya es obligatorio ?',
#  '@MarinadelPilar @Claudiashein No te reúnas tanto marina mi colonia ALTIPLANo 5ta sección en Tijuana, no tiene pavimento, alumbrado, ni seguridad, te necesitamos de verdad.',
#  'Hoy me llena de orgullo felicitarlo por obtener la clasificación a la gran final del Bocuse d\'OR al ganar la categoría "Best Theme on a Plate" junto al equipo Mexicano... no cabe duda que  Baja California siempre brilla en donde quiera que estemos.  (2/3)',
#  '@MarinadelPilar Orgullo Cachanilla',
#  '@MarinadelPilar Pura baba de perico, nada de trabajo, nunca terminó sus gestiones, no es mas que una chapulin de la política. Lo único que ha hecho es estar adulando al patrón.',
#  '@MarinadelPilar Arregla primero el parque de la Col. Santa Rosalía en Mexicali, está hecho un chiquero. El de Fracc. Calafia tiene 20 años sin mejora alguna. Su cancha de basket se construyó hace 30 años. Cuando eras alcaldesa nada hiciste por ambos parques. Vendes humo.',
#  '@MarinadelPilar SIIIIIIIIIIIIIIIIII',
#  '@MarinadelPilar SIIIIIIIIIIIIIIIIIIIIII',
#  '@MarinadelPilar Necesitamos que rescate los parques que hay, antes de gastar en uno tan lejos',
#  '@MarinadelPilar @lopezobrador_ Ojalá todos pudiéramos vivir la "transformación" que tú y tus cercanos viven.',
#  '@MarinadelPilar @lopezobrador_ La lacayez no tiene limites 😡😡',
#  '@MarinadelPilar @lopezobrador_ Hay niveles.  Calderón entra a la Casa Blanca por la puerta principal, con alfombra roja y recibido por Obama.  López entra por la puerta trasera y recibido por el portero.  https://t.co/nsQ6UMRoEl',
#  '@MarinadelPilar @lopezobrador_ Seguro te pagamos para que te la pases chupando huevo al anciano ponte a trabajar tiktogober',
#  '@MarinadelPilar Te paso el link oficial del comunicado.   Ahí vienen las órdenes tal cual.  No hay que aplaudir para tener contento al mesías.    https://t.co/i53bmj6lJ1',
#  'Su labor trasciende en la vida de las y los pacientes, en ustedes encuentran atención y en muchas ocasiones, amistad… ¡Muchas felicidades!  (2/2)',
#  '@MarinadelPilar @lopezobrador_ El orgullo de la gobernadora 🤣🤣🤣  https://t.co/oajXuodj78',
#  '@MarinadelPilar 😡😡😡 …',
#  '@MarinadelPilar @lopezobrador_ Y cuando van a estar en el puesto que se les dio ????',
#  '@MarinadelPilar @lopezobrador_ #EsUnHonorEstarConObrador',
#  '@MarinadelPilar @lopezobrador_ Así como esta fuga dw agua potable en Tijuana, así desperdicia la deformación de 4ta recursos, dilapida nuestros impuestos en publicidad, nulo resultados, asi se irá este su gobierno y el de su amo al caño  https://t.co/74PT471XTu',
#  'Porque el trabajo por el desarrollo y bienestar de nuestra gente no tiene descanso, vamos con el #CorazónPorDelante.  (2/2)',
#  '@MarinadelPilar Ahí le paso la lista de los cromadores oficiales,  ¡Hay perdón, ahí está usted !  ¡ Ups !  https://t.co/GAfTL0yEAu',
#  '@MarinadelPilar @Claudiashein Y como para cuando te pones a trabajar por BC . Basta de estar en eterna campaña pareses presidenta de morena y no gobernadora che vieja stpda',
#  '@MarinadelPilar @lopezobrador_ Eso fue lo que propuso.  Con esto regreso.  Deberías estar con los bajacalifornianos. No con el presidente. Que te quede bien claro.  NO TE LE DEBES A ÉL.   https://t.co/41DgkkLgsj',
#  '@MarinadelPilar @lopezobrador_ 🤦🏻\u200d♂️ los posicionamientos eternos para defender las cagadas del viejito',
#  '💧Así mismo, reiteramos el trabajo que seguimos realizando 24/7 por el abasto de agua en los municipios de la zona costa, no quitaremos el dedo del renglón.  (3/3)  https://t.co/Y2SGCf210F',
#  '💉Gracias a la participación de madres y padres de familia, ya son 105,137 las niñas y niños de 5 a 11 años vacunados en Baja California.  (2/3)  https://t.co/gwAbX73Qny',
#  '@MarinadelPilar Ojalá todas las madres puedieran llevar a sus hijos al trabajo, como usted, pero ellas si tendrían que trabajar de verdad 🥲🥲',
#  'Estoy en contacto con Fiscalía del Estado para conocer las ultimas novedades en la investigación de este triste y lamentable crimen que no debe quedar impune, aplicaremos toda la fuerza del estado en su solución.  (2/2)',
#  '@MarinadelPilar  Que hace Bonilla en el senado ?',
#  '@MarinadelPilar Ponte a trabajar pinche huevona!! Maldita narcotraficante.',
#  '@MarinadelPilar @Claudiashein Gobernadora, a seguir el buen ejemplo del gobierno de @Claudiashein y @lopezobrador_. Primero los pobres.',
#  '@MarinadelPilar Como que porque habrías de esconderte?',
#  '@MarinadelPilar @Claudiashein Que recarajos haces con la Shamebaum  si BC esta ardiendo con tanta inseguridad.  https://t.co/Y6laOWbnjV',
#  '@MarinadelPilar @Claudiashein Que tal estuvo el paseo marina?',
#  '@MarinadelPilar @Claudiashein A buen árbol te arrimas  https://t.co/KotVRczEpC',
#  '@MarinadelPilar @Claudiashein Como pierde el tiempo Sra. Gobernadora',
#  '@MarinadelPilar @Claudiashein Claudia es una gran profesional en el tema de la movilidad. En la CDMX están cambiando a marchas forzadas el transporte público. Enhorabuena',
#  '@MarinadelPilar @Claudiashein Me gusta la blusa de Claudia, fuera de eso no tengo nada bueno que decir.',
#  '@MarinadelPilar  @Claudiashein',
#  '@MarinadelPilar @Claudiashein ¿Cuál fue el resultado de esa reunión? ¿Podría informarnos cuáles son esos planes?',
#  '@MarinadelPilar @Claudiashein Línea 12 👁👁',
#  '@MarinadelPilar',
#  '@MarinadelPilar @Claudiashein Las futuras primera y segunda Presidenta de Mexico',
#  '@MarinadelPilar @Claudiashein Los proyectos de movilidad de doña claudia incluyen explotar y derrumbar trenes con pasajeros, a la vez que bloquear líneas de transporte público dificultando el tránsito de los ciudadanos que se transportan por métodos públicos, ¿Está segura de querer aplicar eso en BC?',
#  '@MarinadelPilar Ya creció el gringitou',
#  '@MarinadelPilar Unas comen tacos en la calle ...usted utiliza a un menor de edad para fines políticos....',
#  '@MarinadelPilar Una mujer que utiliza sus hijos con fines políticos no es empoderada.. es una Abusiva',
#  '@MarinadelPilar @Claudiashein Góber nada más un favor que no sea el metro, ya ve que se le caen a la señora 😬',
#  '@MarinadelPilar Ojalá todas las mujeres tuvieran la misma oportunidad que usted 🙏🏻',
#  '@MarinadelPilar Es falso que eso se puede hacer, bueno ella puede por que tiene chofer, guardaespaldas y gente que le ayuda, pero en la vida real eso no se puede y súmele que el actual gobierno hasta cerro guarderías y que el transporte es una basura en BC así como las vialidades',
#  '@MarinadelPilar Marina, te van a cerrar carreteras por incumplidas. Los ciudadanos están hasta la madre de las mentiras de Morena.',
#  '@MarinadelPilar No.  Discúlpame  eres exhibicionista al igual que Samuel García Sepúlveda y esposa',
#  '@MarinadelPilar está bien, pero sobre todo deberías ser Gobernadora de Baja California, trabajar por el estado. Eso es más importante para nosotros.',
#  '@MarinadelPilar Sigue la paseadera!',
#  '@MarinadelPilar La cara de " NO ENTIENDO NI MIERDA"',
#  'Hemos mantenido un diálogo muy productivo en la búsqueda de seguir sumando esfuerzos por proyectos que transformen a Baja California, siempre priorizando el cuidado del medio ambiente y nuestra gente.  (2/2)  https://t.co/niBPOrZtxe',
#  '@MarinadelPilar Y tapan la imagen ... Dios míos, no fuera una pareja de g4ys follndo por qué eso no lo tapan, la hipocresía',
#  '@MarinadelPilar Eres una MUJER ... con eso es por demás suficiente. Pd:De una madre a otra, que hizo su carrera, crió a su hija sola, enfrentó Miles de adversidades y hoy vive en absoluta Gratitud.',
#  '@MarinadelPilar El Mazateño…🌮🍤 y El Franc…🌮🥩🥑🤤',
#  'Fue un placer conocer un poco más de la tan amplia historia con la que cuenta este emblemático lugar. 🇲🇽  (2/2)  https://t.co/GRzW8ZT01H',
#  '@MarinadelPilar Esta estampilla no puede retratar de mejor manera el estado de BC  https://t.co/L6sQDGckhv',
#  '@MarinadelPilar @RocioBarcenaM @CorreosdeMexico Pero como!! Otra vez no estas en el estado cumpliendo tus funciones ? Ese @mario_delgado te tiene toda loquilla tiktogober',
#  'Ha sido un placer, Directora ¡En Baja California la esperamos con las puertas abiertas!  2/2',
#  '@MarinadelPilar @AntonioAttolini Por que te fuiste a parir a Houston y no a Venezuela?',
#  '@MarinadelPilar Ridícula póngase a jalar.',
#  '@MarinadelPilar  y otros tantos',
#  '@MarinadelPilar Quiero uno para limpiar el WC',
#  'Conoce #TasteAtlas:  https://t.co/eI5oYtnvNE 🌮  Aquí podrás encontrar la lista de las mejores taquerías de México 🇲🇽',
#  'Hoy la felicitación va para los riquísimos Tacos el Yaqui, Tacos el Poblano, Taquería el Poblano y Asadero Acatlán de Juárez, porque #TasteAtlas los reconoce como “Los mejores tacos del mundo”… ¿Ya los probaron? Platíquenme cuáles son sus favoritos...',
#  '@MarinadelPilar Lic.  le mando saludos desde Otay módulos. de igual manera le quiero pedir si nos ayuda con solicitar al gobierno federal para que se extienda las fechas para regular los autos chocolate. Ya que actualmnt no hay citas y todos sabemos que lo ocupamos para el trabajo. Bendicions',
#  '@MarinadelPilar ❤️',
#  '@MarinadelPilar Me da gusto por el sr. que aun trabaja para comer, se le ve humilde y pues es buena idea, basura a cambio de dinero, es extraño, pero tambien se puede vivir de los tarad@s',
#  '@MarinadelPilar A su primer damo ex panista le gusta 🤣ahora todo un moreno, vividor 🐀',
#  '@MarinadelPilar No ande comprando basura. Por cierto: ¡Pero que nivel de arrastradez!',
#  '@MarinadelPilar Muy bien Marina, aportando al comercio ambulante, a la ilegalidad! Preguntales cuanto les cobran de piso a esos señores! Preguntales tambien si estan felices con el AIFA, la refinería y el tren maya!!!',
#  '@MarinadelPilar Seamos sinceros Tijuana dista mucho de ser un lugar increíble, Tijuana simplemente es el punto de partida para el sueño americano en California, fuera de eso nadie quiere vivir ni nacer aquí, por ejemplo tus hijos mejor nacieron en California !!',
#  '@MarinadelPilar  https://t.co/RDYlcJuLw6',
#  '@MarinadelPilar No es necesario tirar dinero en algo que no va servir. B.C necesita muchas cosas pero esta obra ridícula no.',
#  '@MarinadelPilar  https://t.co/NRuwWE42NS',
#  '@MarinadelPilar Hay mejores maneras de malgastar el dinero.',
#  '@MarinadelPilar Wow queee compra!!! Seguro le costó dos pesos como lo que en realidad vale… no sería mejor que se pusiera a gobernar?',
#  '@MarinadelPilar Que asco',
#  '@MarinadelPilar Cuadras más adelante hay unos de Freddy Krueguer…. Aguanta!  Que afán de meterles traumas a los morros desde pequeños.',
#  '@MarinadelPilar Hasta donde llega la lambisconería… que quieres ahora? Impunidad? O crees que porque el narco te regaló una gubernatura ya puedes ser corcholata????',
#  '@MarinadelPilar Pinché vergüenza,',
#  '@MarinadelPilar 😂',
#  '@MarinadelPilar  https://t.co/lUS0ik807L',
#  '@MarinadelPilar Que pena da el “pueblo mexicano” me cae',
#  '@MarinadelPilar Qué perro asco...  👉Pobre bebé',
#  '@MarinadelPilar Ridícula',
#  '@MarinadelPilar Póngase a trabajar en su estado Marina. Ya déjese de andar paseando. Deje de estar haciendo actos anticipados de campaña. Arrastrada',
#  '@MarinadelPilar Y mientras el estado donde debería estar gobernando lleno de violencia ! Cada vez peor!',
#  '@MarinadelPilar Yo no se por qué la critican!!, están bien “bara bara” y a mi me sirven para jugar  🎯 y para calmar a la perrada de pitbulls de mi vecino!!, siempre es fácil encontrarlos!! 🤣😂🤣😂',
#  '@MarinadelPilar De penita ajena esta gober.......póngase a gobernar en vez de andar de turista electoral....',
#  '@MarinadelPilar Ridícula, profesando el culto a la personalidad.',
#  '@MarinadelPilar Lo que eres capaz de hacer y humillarte con tal de tragar con manteca,deberías de tener cuidado y no meter a tu hijo en tus videos, ten en cuenta que un día crecerá y el no tiene la culpa por los errores y atrocidades cometidas por su madre.🤦🏻\u200d♂️',
#  '@MarinadelPilar  https://t.co/s4rwln9Q9g',
#  '@MarinadelPilar Aaaahhh yo quiero también un Beetlejuice, mañana voy por el mío al centro ‼️‼️  https://t.co/gfGpI2zqWa',
#  '@MarinadelPilar Que mala madre eres, pobre niño lo vas a asustar con ese muñeco, de una vez cómprale uno de Chucky',
#  '@MarinadelPilar The American baby, de shopping afuera del Palacio, wouuuuuuu....',
#  '@MarinadelPilar 🙄🙄🙄🙄🙄',
#  '@MarinadelPilar Hermosa comprá',
#  '@MarinadelPilar Como le fue en playa del carmen mi gober? Hay mucha chamba por acá, no descuide el estado......',
#  '@MarinadelPilar Pura baba de perico. Pura simulación. Hay lugares y están completamente descuidados. Pero sigamos con el circo.',
#  '@MarinadelPilar Puro viajar y… trabajar cuando?',
#  '@MarinadelPilar Malisima para gobernar a pero pa las fotos y el tiktok la numero 1',
#  'Les deseo mucho éxito son un orgullo para Baja California y desde la distancia estaremos apoyándolos. \U0001faf6🏆  (2/2)',
#  '@MarinadelPilar Espero que en el caso de Tijuana.  Nuestra Presidenta, le de atención al Parque Morelos y De la Amistad.  Es un tiradero, Muy sucios, están muy abandonados. Invito a la Sra. Montserrat, que los supervise . Por favor.  Urge su atención',
#  '@MarinadelPilar No mames Marina, las que ya existen las tienen totalmente descuidadas y abandonadas. Haz algo ya.',
#  'Gracias a su entrega logramos obtener una medalla de oro, 5 de plata y 8 de bronce; estoy segura que con el esfuerzo y dedicación que demostraron, vendrán resultados fantásticos para ustedes y nuestro Estado a futuro.🥇🥈🥉  ¡Muchas Felicidades! 🎉  (2/2)  https://t.co/H7OEHok8c1',
#  'Nada se compara a pasar un lindo día al aire libre en familia y con esto, haremos de Baja California un Estado con mejor calidad de vida. ❤️  (2/2)',
#  '@MarinadelPilar Sra  en el Murua el trasporte es pésimo no quiero que su gobierno sea corrupto como todos chéquelo por favor con mucho respeto 🙏🙏🙏',
#  'Velar por los más necesitados, reiterando que, por el bien de todos, primero los pobres; su gran trabajo, me lleva a ser su aliada y decirles que estaré junto a ustedes para seguir ofreciendo una sombra a las y los más vulnerables.  (2/2)',
#  '¡Albergue Peregrino, gracias por abrir la puerta y poner el corazón por los que más lo necesitan!  (3/3)  https://t.co/DqYQbHBK6K',
#  'Es un honor contar con la labor de este lugar, que ofrece servicios gratuitos a la población migrante, como atención médica, orientación social, educación y talleres de formación de manera temporal para brindarles un techo y bienestar.  (2/3)  https://t.co/QvSYp0i96L',
#  '@MarinadelPilar De concretarse esos proyecyos, Marina marcara historia en BC como el mejor gobernante en este tan hermoso Estado.',
#  '@MarinadelPilar Muchas gracias Gobernadora',
#  'Su trabajo es de suma importancia para la seguridad de Baja California y por lo tanto, es una prioridad garantizarles la tranquilidad que merecen con un mejor servicio.  (2/2)',
#  '@MarinadelPilar La mitad de ellos cooperan con los Arellano y el CO',
#  '@MarinadelPilar  https://t.co/5EjEUdX0eb',
#  '@MarinadelPilar Con el pistolon por delante  https://t.co/MVMzhlPyMO',
#  '@MarinadelPilar Ahí esta la pura billetiza para el 🐀 Carlos Torres panista corruptos 🐀.',
#  'Hemos entregado esto y más en nuestra Jornada con el Corazón Por Delante en Mexicali; nos vemos muy pronto en tu colonia.  (3/3)  https://t.co/6qPTOm8FLE',
#  '📦 1300 despensas 💻 10 equipos de cómputo 📧 300 vales \U0001faaa 500 tarjetas Ilumina Tu Día 💜 300 tarjetas Violeta 🌳 250 árboles 🦽 13 sillas de rueda, 13 bastones y 13 andaderas 💉 Vacunación a menores en caravanas de salud   (2/3)  https://t.co/lW4tjRFGnk',
#  '@MarinadelPilar @DIF_NMX Buenas para las fotos y el tiktok . Para dar resultados pura vrg',
#  'Gracias por apoyar y acercarte a Baja California; tu liderazgo y solidaridad por las y los que más lo necesitan merecen todo mi reconocimiento.  (2/2)',
#  '🎥:  https://t.co/zMnOo9VEC9',
#  '@MarinadelPilar También traemos el agua vivo y se enojó el🇺🇸FBI de Biden.  Estimada🇲🇽gobernadora, se encuentra preso TORBEN SØNDERGAARD, acusado falsamente del trafico de armas en BCN. Le ruego que Ud., como jefa del gob. del estado declara si hay evidencias en su contra.  https://t.co/x2sLwX6rcU',
#  '@MarinadelPilar Espero verla hoy señora Presidenta.  https://t.co/mauLD3tvYx',
#  '@MarinadelPilar Me gustaría más Mexicali sin baches',
#  '@MarinadelPilar Programa de limpieza debería tener por lo menos Tijuana es un basurero , ya ni decir de las vías de transporte y violencia sería mucho pedir',
#  '@MarinadelPilar @NormaMXL oiga para cuando arreglan el trafical que se hace en el teran teran ?',
#  '@MarinadelPilar Claro ya se estaban caducando las vacunas, por eso las aplican.',
#  '@MarinadelPilar Y los baches de Tijuana y la basura y el tráfico y la inseguridad y el transporte público masivo ...cuando? Hay tijuana como me dueles!',
#  '💧 Proyecto de Ecoparques no afecta al agua. 🌊 Proyectos para impulso a San Felipe y San Quintín.  ¡Nos vemos la próxima semana! ❤️  (2/2)',
#  '@MarinadelPilar Muy original. Hasta en la falta de resultados copiando al viejito',
#  '@MarinadelPilar @MarinadelPilar que raro que no hay bots aqui alagandote como en Facebook.',
#  '@MarinadelPilar @m_ebrard Si pagan buenos salarios y respetan los derechos laborales de los trabajadores  Bienvenidos',
#  '@MarinadelPilar @m_ebrard Si es una Gran noticia  !! A darles Seguridad a nuestra gente, para que inviertan más',
#  '@MarinadelPilar Ya veremos...',
#  '@MarinadelPilar Gracias por tomar en cuenta al poblado de La Presa, es un lugarcito mágico.',
#  '@MarinadelPilar Excelente Sra nuestra de ejemplo a Méxicali, siga así y verá el amanecer del éxito tocando a sus puertas',
#  '@MarinadelPilar Muy bien gobernadora, hasta que va a hacer algo bueno 🤝',
#  '¡Bienvenidos al Parque Esperanto, el pulmón de Tijuana!🏞️💚  (2/2)',
#  "Estas 130 hectáreas, equivalentes a multiplicar 3 veces la superficie del Parque Morelos, forman parte de ''Más Parques, Más Vida''.  ¡Gobierno y organizaciones estamos unidos por dar un respiro a Tijuana!💚  (2/2)  https://t.co/S1Iit8ny8m",
#  '@MarinadelPilar Seguro es grande tu interes porque tu marido el mister been ya compro algunos terrenos en esa zona . La quieren aplicar como con el centro historico',
#  '@MarinadelPilar Pobre niño para que lo expone . Pero entiendo en su cabeza no hay mas que cromar sable a don kks y su 4ta putrefaccion por eso no entiende que lo que hace esta nal',
#  '@MarinadelPilar @Claudiashein @EvelynSalgadoP @MaraLezama Arrastarse es un cambio?',
#  '@MarinadelPilar Así como dijiste que se reubicaria el basurero municipal de la Calzada Héctor Terán no hiciste absolutamente nada Marina Del Pilar Olmedo #FueraMorena',
#  '@MarinadelPilar Jaja un aeropuerto que nadie usa y la refinería sin combustible ustedes son igual o poer',
#  '@MarinadelPilar Cuando observó la indiferencia del pueblo de Baja California a las publicaciones de su gobernadora... entiendo que nunca nos hemos sentido representados... @lopezobrador_ @PartidoMorenaMx lo pagarán en las próximas elecciones😬',
#  '@MarinadelPilar Me toco conocerlo y tambien aprendi sobre su vida personal y su reclusion por ser opositor politico gran hombre.',
#  '@MarinadelPilar NO SE COMO PÚEDES ADMIRAR A UN VIEJILLO ASESINO TUPAC AMARU QUE EJECUTABA PUEBLOS ENTEROS DE INDIGENAS',
#  '@MarinadelPilar Bebé hermoso Diego José en compañía de sus guapos padres Que Dios Nuestro Señor Los Bendiga 🙏🙏🙏 y Proteja En Todo Momento',
#  '@MarinadelPilar Bendiciones para ti y la familia',
#  '@MarinadelPilar ¿Le platicó que hoy anduvo trabajando en tomarse fotos con una pala en plataformas?',
#  '@LaydaSansores Ya póngase a trabajar doña',
#  '@LaydaSansores @VernicaBolaos7 ¡SIII! 👏👏👏',
#  '@LaydaSansores Déjate de mamadas y ponte a gobernar y haber cuando sale algunos audios tuyos o te protegiste bien no creo ya saldrán ya saldrán',
#  '@LaydaSansores No hagas caso de los que dicen que estas fea, no saben como queda uno después de los accidentes, tú levanta la cara!',
#  '@LaydaSansores Deja tu show, saltimbanqui politiquera.',
#  '@LaydaSansores Pero están mame y mame qué fuera Morena, todos son la misma mierda ches Hipócritas de 5a.',
#  '@LaydaSansores Y tus audios que paso ahí,aaasss que son falsos verdad gordaaaaa¡¡',
#  '@LaydaSansores Duro con el Layda, que no se te escape. Es hora de acabar con el PRI y con esta bola de bandidos.  Hay que cortar las cabezas de esta serpiente que tiene cabezas de PRI PAN PRD MC FRENA VA POR MÉXICO ETC. Todo México te apoya. Saludos Layda y Felicidades.',
#  '@LaydaSansores Se rumorea de un  #AudioDeAlito con ejecutivos de Playboy. 😱😱😂😂😂  https://t.co/I1HEZXrkjF',
#  '@LaydaSansores La neta neta neta  , la basura de alito por mas que niegue y diga que es un delito que filtren  esas conversaciones , lo esta  haciendo mierda ..',
#  '@LaydaSansores Firmes y listos gobernadora👍🏼,  Darle Con todo a esta alimaña de vandALITO morreno y toda el #PRIANRDMCVendePatrias #PRIANUnPeligroParaMexico porque son #TRAIDORES_A_LA_PATRIA',
#  '@LaydaSansores Eres igual de vil, vulgar, ridícula , ratera, prepotente , mentecata, irresponsable y asquerosa que tu patrón al que tanto odias .',
#  '@LaydaSansores @lopezobrador_ Ese “querido presidente” mentecato y sin escrúpulos? La hipocresía a todo lo que da jajaja',
#  "@LaydaSansores @Rafaherrera1983 Quiero ver Pack's  No se pierdan este martes el mejor programa, donde @alitomorenoc  nos enseña  sus vilezas y cobardías",
#  '@LaydaSansores Pasa este audio.  Es muy bueno  https://t.co/pFBYmFyJbD',
#  '@LaydaSansores me tiene tan emocionado el martes de jaguar tanto asi como las mañaneras, un seguidor mas de la estimada layda.',
#  '@LaydaSansores Ahí estaré 💯💪🏼🇲🇽💃🍿🥂',
#  '@LaydaSansores Invita a Sin Censura !!!  Con @_VicenteSerrano',
#  '@LaydaSansores Y… si te pones a gobernar, en lugar de estar atendiendo venganzas personales desde el poder ???',
#  '@LaydaSansores Y va a transmitir también el audio de su sobrino pidiendo dinero',
#  '@LaydaSansores Ansias locas !',
#  '@LaydaSansores Me gustó en el que dices que @lopezobrador_ es un mentecato  👍🏻',
#  '@LaydaSansores Ya quiero que sea martes 😃😃 o',
#  '@LaydaSansores  https://t.co/71uTG6CvsX',
#  '@LaydaSansores Hacen escándalo por lo que un imbécil dice en privado y no dicen nada por las pendejadas que dice el kks @lopezobrador_ todos los días en público!! Pronto se irá don pendejo y ya nos veremos!! Al tiempo!!',
#  '@LaydaSansores mi chava eres ejemplo de la PROSTITUCION política, de PRIISTA a PERREDISTA y luego MORENISTA, así como tú “amiga” Lily Téllez que de MORENISTA vendió las nachas al PAN, como tú podrás comprender',
#  '@LaydaSansores  https://t.co/vuVsztdAlu',
#  '@LaydaSansores  https://t.co/6lrD5dLIVJ',
#  '@LaydaSansores Es usted la viva representación de (CENSURA TUITER)...',
#  '@LaydaSansores  https://t.co/yUqvMD04V2',
#  '@LaydaSansores A darle con todo, y que sigan llorando las dipu... quién las manda a ser tan rentables.',
#  '@LaydaSansores @tiosamm14  https://t.co/ST9FEoknRk',
#  '@LaydaSansores @JRlopezbeltran Ya escuchaste el nuevo audio de tu papi.?   https://t.co/h9maI6SlGC Te lo dejo y me retiro leeeeentamente.! 🤣🤣🤣',
#  '@LaydaSansores Deje de mamar y póngase a gobernar ese wey está muuuyyy lejos de Campeche',
#  '@LaydaSansores Ni la hora nacional tiene tanta difusión.',
#  '@LaydaSansores Sería mas serio si lo llevara a la justicia, con hechos, pero más beneficioso para ustedes, el descrédito 😤',
#  '@LaydaSansores No que no se nos terminen los audios del tal alito el corrupitito, nos recuerda que el PRIAN NUNCA CAMBIA',
#  '@LaydaSansores Como buena para nada Pan Y Circo para el pueblo bueno y sabio como dice el Pendejete de Palacio Nacional hay la llevan solo haciendose pendejos',
#  '@LaydaSansores Esperamos con palomitas.',
#  '@LaydaSansores @chef_zurita ¡ Pon el audio de tu sobrino!',
#  '@LaydaSansores ¿No que ya no ibas a meter más audios?',
#  '@LaydaSansores Y que nos puede decir del fracaso de este gobierno?  Ya falta menos para que salgan huyendo del país!  #MorenaCuevaDeDelincuentes  https://t.co/H909SQZQ32',
#  '@LaydaSansores Gracias layda, bendito sea Dios que si vas a poner otro audio para ya acabar de enterrar a esa p* inche lacra',
#  '@LaydaSansores Debería de poner en orden a sus familiares..que siguen robando al país',
#  '@LaydaSansores Ahi te hablan @alitomorenoc !!!!',
#  '@LaydaSansores @lopezobrador_ Estás rodeado de hienas analfabetas y oportunistas',
#  '@LaydaSansores ¿Realmente cree que con estos ataques está ayudando a su propia carrera?? A nadie le agrada estar con alguien que sólo dedica su tiempo a atacar y no a proponer... Que lástima que use su potencial en estas tonterías!. Acabó con el PRI, de la mano de su carrera...',
#  '@LaydaSansores Changa 🐷  https://t.co/xi8TXJO4MO',
#  '@LaydaSansores Vomitivo programa de la impresentable gobernadora',
#  '@LaydaSansores Es laura en América versión mexicana?',
#  '@LaydaSansores Así se hacen grabaciones falsas  https://t.co/9Cbu1kjqFs',
#  '@LaydaSansores 🤮',
#  '@LaydaSansores @lopezobrador_ Claro que no está sólo....lo acompañan la bola de rateros chafarderos, lameqlos cómo tú.',
#  '@LaydaSansores CHTPM cara de mascara de mona de cartón',
#  '@LaydaSansores Vieja ridícula pon el audio de tu sobrino bruja no tienes vergüenza eres gobernadora corrupta o eres de reality show si no haces circo no ahí quien te pele verdad, viejilla horrorosa',
#  '@LaydaSansores Quién carambas haría caso de algún testimonio que diera alguien a quien le llaman " el fisgón"  En qué mundo vive señora tigresa... La ley la ha vuelto un show cómico mágico y musical Haga su trabajo Dele a los que votaron por ud razones para no mandarla a la ching@d@',
#  '@LaydaSansores Atención. Este miserable va a usar todos sus recursos para intentar tirar la transmisión.',
#  '@LaydaSansores Alguien que me diga de donde saca los audios por fa',
#  '@LaydaSansores Otra vez?   De dónde los saca oiga?  -Pregunta seria',
#  '@LaydaSansores Ponte mejor a gobernar y trabajar vieja payasa',
#  '@LaydaSansores Señora sus acciones son tan patéticas como su rostro, si alguno no supiéramos quién fue el Negro Sansores usted tendría algo de crédito pero ese tipo era peor quela kagada de Alito',
#  '@LaydaSansores Layda, Layda eres igual o peor que Alito, falsa para todo.( Hasta en tu persona, con solo ver tanto implante, botox, etc.,etc.)',
#  '@LaydaSansores Sabe que la única que se denigra es usted, verdad?',
#  '@LaydaSansores Yo que Alito soltaba el pack de la Sansores para que se le quite!!.',
#  '@LaydaSansores Necesitamos que le de la última estocada al buey ese,  acompañado de una denuncia y de una vez la orden de aprehensión para evitar que se evada de la justicia',
#  '@LaydaSansores También podrías hablar de los contratos millonarios a tu familia!!.',
#  '@LaydaSansores @lopezobrador_ Por supuesto que no...  Esta rodeada de pura rata y puro p3ndej0',
#  '@LaydaSansores @juncalssolano Mejor póngase a trabajar y deje de perder el tiempo 😒  https://t.co/KMK5WMr0cn',
#  '@LaydaSansores Solo vi, audiodelito.',
#  '@LaydaSansores  https://t.co/AY0h3BjXCU',
#  '@LaydaSansores No aprendiste, sigues acumulando Karma, te va a salir el tiro por la culata de nuevo. No tienes honor, ni valores.',
#  '@LaydaSansores Oye, ya escuchaste este audio? Que opinas ?   https://t.co/kkFKtIGotE',
#  '@LaydaSansores Mejor debería de dedicarle un programa a las remembranzas , La Sansores debería contarnos a cuantas V les sacó brillo en sus 30 años de priista',
#  '@LaydaSansores Y si mejor te pones a gobernar? Los audios y el Botox que te pones, son igual de falsos!  Así la 4ta',
#  '@LaydaSansores Ya ponte a trabajar Gobernadora de Campeche, deja que las autoridades hagan su trabajo y que enjuicien a todos los CORRUPTOS incluyendo a la Gobernadora de Campeche.',
#  '@LaydaSansores Gobernadora por favor no deje de darle vergazos salves a este inútil dé alito 🙏',
#  '@LaydaSansores Si vas a dejar el estado de Campeche como saqueaste y desgraciaste la Alcaldía Álvaro Obregón pobres campechanos cómo gobernante eres un asco!!!',
#  '@LaydaSansores Mejor que explica el audio de tu sobrino pidiendo 80 millones de moche, son igual que el PRI',
#  '@LaydaSansores 😂😂😂🤣  https://t.co/rBZHgKpROl',
#  '@LaydaSansores "...Mi abuelo era un hombre muy valiente, sólo le tenia miedo a los idiotas. Le pregunté por qué y me respondió: porque son muchos.. y al ser mayoría, eligen hasta al presidente". Facundo Cabral  https://t.co/RS7cU2rLtb',
#  '@LaydaSansores Vaya vaya!!!!  https://t.co/hngG9945U5',
#  '@LaydaSansores No cabe duda que esto de “gobernar” no se les da, lo que les queda muy bien es el circo 🤡 que hacen. Pónganse a trabajar o si les quedó grande el puesto, renuncien!!',
#  '@LaydaSansores Que su trabajo no es gobernar? Ahora es comunicólogo.',
#  '@LaydaSansores Que nivel de bajeza y cinismo tienes corrupta inmunda',
#  '@LaydaSansores ¿No deberías de estar gobernando tu estado, en lugar de andar difundiendo esta clase de información? ¿Para eso te votaron? No eres distinta, tú eres la misma escoria política de la que pretendes exhibir.',
#  '@LaydaSansores Eres un asco de persona',
#  '@LaydaSansores Queremos escuchar todo todo todo, por favor 🙏',
#  '@LaydaSansores Decirle que es una mierda seria piropo, pinche cuasimodo',
#  '@LaydaSansores No sea huevona y póngase a trabajar en lugar de andar con pleitos de verduleras',
#  '@LaydaSansores Mejor expliquemos su audio donde dice lo que piensa realmente de @lopezobrador_ El @fisgonmonero ??? Vaya credibilidad.',
#  '@LaydaSansores Layda TVNotas qué nivel tan bajo tienes.',
#  '@LaydaSansores @lopezobrador_ O digas ramerias @LaydaSansores',
#  '@LaydaSansores @juncalssolano Alito:  https://t.co/Umi2OGhyU1',
#  '@LaydaSansores ¡Ya dejalo por favor! Ya no sabe que más decir. Solo dice que son audios truquedos y no dijo lo que dijo',
#  '@LaydaSansores @lopezobrador_ Usted Layda es una vergüenza nacional, representa lo peor del viejo y del nuevo PRI',
#  '@LaydaSansores Gracias Layda Sansores  Estaremos listos para apoyar la democracia y desenmascarar a los hipócritas, tiranos PRIANRDistas  ( Gracias a los priistas que quedaron fuera de la jugada del criminal Alejandro Moreno N. y que comparten sus grabaciones )',
#  '@LaydaSansores Cuando vas dar anuncios de lo que esta haciendo por su estado',
#  '@LaydaSansores Alito no es santo de mi devoción...pero no se le olvide @LaydaSansores CON LA MISMA VARA QUE MIDES SERÁS MEDIDA... espero no tengas cola q te pisen, porque...',
#  '@LaydaSansores Esperamos que también ponga, el audio de su sobrino, pidiendo dinero para dar un permiso de construcción. 80 milloncitos.',
#  '@LaydaSansores Ojalá y fuera para “chingar a todos los corruptos”, pero sólo es un golpeteo político, no dudo que Alito tenga cola que arrastrar, pero casi todos  los políticos de hoy la tienen. Tanto dentro y fuera del gobierno, nos harán un favor si se destrozan todos. Escoger el menos peor.',
#  '@LaydaSansores Hominikaka, eso eres HOMINIKK, hija del KK’s',
#  '@LaydaSansores @lopezobrador_ Reinita, López está rodeado de excremento como tú.  https://t.co/H2r140k9ME',
#  "@LaydaSansores @lopezobrador_ Ches ratas de alcantarilla tú y el kk's",
#  '@LaydaSansores Oye pndja Chucky versión nopor,y tu audio exponiendo a @lopezobrador_ cómo el mentecato,corrupto,inepto y vergüenza nacional que es !? 🤣🤣🤣🤣🤣🤣',
#  '@LaydaSansores @juncalssolano  https://t.co/2rlSb8LVsh',
#  '@LaydaSansores Ya Dońa @LaydaSansores ya asta se me terminaron las 🍻 de estar platicando que usted es una chingona y con 🥚🥚🥚🥚que le está sacando toda su 💩 a esas Ratas PRIANISTAS saludos desde mi hermoso y jodido Perote Veracruz gracias a @Pepe_Yunes  Perote no avanza  https://t.co/YT4geJdoPH',
#  '@LaydaSansores ahi estaremos como siempre apoyando a mi tia layda todos los martes.',
#  '@LaydaSansores R I D I C U L A',
#  '@LaydaSansores @rcobilt ¡¡¡Nooooo!!!!!  Tía Layda que no sea el último, queremos escuchar todas las hras. de grabación. Ahí estaré puntual.',
#  '@LaydaSansores Por mi puedes meterte el programa por donde te sale lo que comes.',
#  '@LaydaSansores Se me hace muy cagado que la gobernadora de Campeche tenga un programa de tv k c llama “martes de jaguar” :v @maximilianocb98',
#  '@LaydaSansores Que bueno que recapacitaste Layda. A seguir conociendo el teje maneje del @PRI_Nacional, ya ante había un gordo asqueroso que manejaba un res de prostitución dentro pero, parece que no se acabó. Así son ellos! Ya tengo mis palomitas y tbn pensé en una michelada.',
#  '@LaydaSansores Tamb pones el del peje. Equidad. Longe...mo..co.',
#  '@LaydaSansores Noooooooooooo!!!!!! 😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭 #SelvameDelJaguar😂😂😂😂😂  https://t.co/YoTa4sGlaL',
#  '@LaydaSansores Solo si se pone máscara para cubrir su cara deforme',
#  '@LaydaSansores Que vergüenza da señora en vez de ponerse a trabajar su único logro son los audios de un personaje igual o peor de corrupto que usted o del negro Sansores, pobre Campeche lo va a dejar pero que la delegación Álvaro Obregón en la Cdmx aquí tiene cuentas pendientes!',
#  '@LaydaSansores @gallotal Ósea que mientras seas del partido en el poder la ley es solo una sugerencia y puede pasársela por donde le de la gana…chingon es los funcionarios públicos del país que en lugar de ser los primeros en respetar la ley son los primeros en violarla',
#  '@LaydaSansores Esta señora si que le puso un nuevo nivel a lo que se conoce como “Guerra Sucia” Pues ni así lograrán postergarse en el poder por que estoy seguro que la oposición tinene preparadas unas buenas bombas para las elecciones. El que se lleva se aguanta! 😂',
#  '@LaydaSansores @gallotal Que no se supone que las comunicaciones privadas son eso PRIVADAS y exponer cualquier información de ellas sin consentimiento de una de las partes involucradas es delito ¿o no ?',
#  '@LaydaSansores El gobierno de Campeche se convirtió en el ventaneado de la 4T corruptos? Que patéticos, en vez de seguir el debido proceso todo lo hacen mal. Ya estuviera procesado Alito pero les gusta el Show y la parafernalia.',
#  '@LaydaSansores Oye Layda y cuando facturabas más de medio millón de pesos al Senado tmb eras austera?? O buscabas cualquier forma para justificar gastos y gustos??',
#  '@LaydaSansores  https://t.co/Nyhiou1Rba',
#  '@LaydaSansores a poco estos no son como los del presi y los suyos que son fake y ya nos enseñaron como los hacen.Mejor comentenos del robo a las plataformas en la sonda de Campeche que se llevaron,en que afecta a Pemex y como van las investigaciones',
#  '@LaydaSansores Cuando no tienes vergüenza y sigues violando la ley. Mal por la investidura de la gobernación. Ahora parece lavandera',
#  '@LaydaSansores Esperemos qué sea tan legal cómo vilontar a las diputadas de la oposición, porqué en palacio nacional dicen qué tú eres la única responsable y supongo qué la ley Olympia contempla algo así. Una mujer viloentado a mujeres con línea desde la presidencia. ¿O no gobernadora?',
#  '@LaydaSansores El comal le dijo a la olla!! Pleito entre corruptazos!!',
#  '@LaydaSansores @DavidChih7 Layda, por eso y mucho más te queremos, si de por si, ya los traes bien bocabagiados, y todavía su pilón, ahí estaremos puntuales en el Martes de Jaguar 🐆❤️❤️❤️❤️❤️',
#  '@LaydaSansores @JoseOrn15607390 Puro político de lavadero pónganse a sacar su gobiernos adelante no sean mediocres para eso según ustedes los puso el pueblo',
#  '@LaydaSansores Le dar chorrillo de nuevo a la Micha 🤣🤣',
#  '@LaydaSansores Chismosa',
#  '@LaydaSansores Póngase a trabajar tan anciana y borlotera',
#  '@LaydaSansores @lopezobrador_ Ya ni le mueva que solo se va a hundir más  https://t.co/kfHQDw3k7G',
#  '@LaydaSansores Ya quiero que sea martes',
#  '@LaydaSansores La vida da muchas vueltas mujer. Hoy te toca estar arriba. Aprovéchalo porque no siempre será así.   Ojalá también termines en el bote tú también porque tienes la cola bastante larga. (Y ni por buena) tu cola de rata 🐀',
#  '@LaydaSansores Layda, tú tienes una muy laaarga cola que te pisen.  El burro hablando de orejas….. Qu  de desfachatez!!',
#  '@LaydaSansores Solo te recuerdo las tranzas de tu sobrino  https://t.co/QJloUAu3yq',
#  '@LaydaSansores Hay que darle la última estocada al corruptazo de @alitomorenoc',
#  '@LaydaSansores @lopezobrador_ Jajajaja son una pantomima.',
#  '@LaydaSansores Guerra de audios, parecen puertos con sus jaladas, sabemos que lo suyo es el chisme de lavandería, pero mejor pónganse a trabajar o al menos intentenlo, se que es mucho pedir para la bola de burros que son, pero pues por algo se empieza.',
#  '@LaydaSansores En sus tiempos de juventud a esta señora yo creo que también le hacen sus fotos como hay ella presume que pasa en el pri... Si alguien sabe quien tiene fotos y videos de ella hágalo saber nos gustaría el como hizo su fortuna actual...',
#  '@LaydaSansores  https://t.co/xkAOtwzKMG',
#  '@LaydaSansores Perfecto, estaré pendiente 👍',
#  '@LaydaSansores Problema de mierda , y si van pura escoria puerta mierda , empezando con ud y rematando con sus invitados de cagada',
#  '@LaydaSansores ¡Oops! 🙊  https://t.co/aI8pbDCLVU',
#  '@LaydaSansores Que Emoción..... gracias por Seguir....',
#  '@LaydaSansores Bruja de 💩💩💩‼️‼️‼️',
#  '@LaydaSansores Con todo Gobernadora 👊💥',
#  '@LaydaSansores Yo no confiaría en una persona rellena de botox y de hialuronico que no acepta que es una anciana',
#  '@LaydaSansores Que persona tan nefasta eres "gobernadora” ¿para eso te pagan un sueldo? Deberías de ocuparte de los verdaderos problemas en Campeche',
#  '@LaydaSansores',
#  '@LaydaSansores Mejor platicanos de tu sobrino al que mandabas por los moches y ponte a gobernar que se supone que eso debes hacer.   https://t.co/CNUSeew3dH',
#  '@LaydaSansores Dedíquese a gobernar y no a hacer el trabajo sucio a su presidente, campechanos por esto votaron? Que tristeza!!!!',
#  '@LaydaSansores ya ponte a trabajar lin may de la 4T',
#  '@LaydaSansores Ponte a trabajar vieja argüendera, votaron por ti para gobernadora no como fiscal, esa no es tu chamba. Y ya no te inyectes botox',
#  '@LaydaSansores @lopezobrador_ @LaydaSansores igual de loco que UD. Aparte de lame patas y corruptos,🤬🤮',
#  '@LaydaSansores Y como para cuando haces la denuncia, ante las autoridades!?? 😒',
#  '@LaydaSansores y si mejor se pone a chambear? No quería para eso ser gobernadora?',
#  '@LaydaSansores @lopezobrador_ Si,, no estás solooo...te sigue una bola de zombies como la trompuda de layda sansores',
#  '@LaydaSansores Esto no le va a gustar a @Adela_Micha',
#  '@LaydaSansores Ya quiero que sea Martes....',
#  '@LaydaSansores A darle con todo a ese corrupto y vende patrias de Vand-Alito mi gobernadora hasta no verlo en la carcel.',
#  '@LaydaSansores AY,ya, si se sienten tan rompe madres, métanlo a la cárcel, el que tiene evidencias manda a la cárcel a un culpable, pero pendejadas de: dicen y salen y bla,bla,bla...me suena a chisme de viejas de lavadero...ya MADURE Sra,de en balde su edad',
#  '@LaydaSansores  https://t.co/XSPb68PMeK',
#  '@LaydaSansores Ah para eso sí convocan a TODOS los medios, si la próxima presidencia la gana cualquier partido de oposición muchos van a terminar en la cárcel, por ejemplo tu!',
#  '@LaydaSansores Pobres campechanos en manos de quien están.....',
#  '@LaydaSansores Layda no estás sola , te admiro .',
#  '@LaydaSansores 👍👍👍👏👏👏',
#  '@LaydaSansores NOS VAS A PONER AL AUDIO DE TU RATERO SOBRINO DONDE SOBORNO CUANDO ESTUVISTE EN LA DELEGACION ALVARO OBREGON?',
#  '@LaydaSansores @lopezobrador_ Layda dicen tus amigas de Tlalpan que cuando regresas al talón?🤣',
#  '@LaydaSansores Apurese por favor que ya me aburrió "La flor de Guadalupe " @LaydaSansores  https://t.co/kTFi61iJxe',
#  '@LaydaSansores Excelente la felicito de  verdad es una mujer muy comprometida con el pueblo ,y comparto su idea de exponer ala vida pública  a este ratero y de esos hay muchos no está sola gobernadora.',
#  '@LaydaSansores El pilón de la temporada 2022. No dudo que se están guardando algunos para el 2023 y los cruciales para el 2024.',
#  '@LaydaSansores Tía, ¿habrá segunda temporada?',
#  '@LaydaSansores @lopezobrador_ Así o más falsa me amiga cara de bagre🤣',
#  '@LaydaSansores CON ANCIAS@@#!',
#  '@LaydaSansores Ya ponte a trabajar chingada madre !! Puras idioteces ! Pobres Campechanos ! Es urgente que emplees tu capacidad en gobernar y traer progreso a tu estado !! No te enfrasques en porquerías !!',
#  '@LaydaSansores Que emoción',
#  '@LaydaSansores @alitomorenoc  @PRI_Nacional  @GPPRIDiputados  @copppal_oficial  @MexVaporMex  Gracias Gobernadora Layda por exhibir al pinche ratero de alejandro',
#  '@LaydaSansores Y ya vio el de su mesías o ese lo ignora tiene usted el síndrome de la gallina ciega',
#  '@LaydaSansores @MalthusGamba 😂😂😂😂',
#  '@LaydaSansores Ay no! 🙂😁😔😎😭😉 No quiero que se acabe. Está furioso @alitomorenoc Ya hasta le recordó a su primogenitora #@?!#@ a Osorio Chong 😕😌😂  https://t.co/4tQkJXa439',
#  '@LaydaSansores Usted échele, yo acá le acomodo. 😁😂😆',
#  '@LaydaSansores Deberia ser " los martes de café por la noche , Con el padrote alito"',
#  '@LaydaSansores Justamente de los políticos como Layda y Alejandro estamos cansados. Personajes de caricatura sin valores ni escrúpulos echándose 💩todos contra todos en lugar de gobernar, nos queda claro q lo de ustedes es solo el Poder p robar, los ciudadanos, el país les importa poco.',
#  '@LaydaSansores RIDICULEZZZZ  https://t.co/dmH4zOm60p',
#  '@LaydaSansores @juncalssolano Les pido de favor que retomen la misma estrategia que traía  el ex presidente nacional del pri.el rey de la basura, existe mucha tela de que cortar..  es la misma porqueria y  no se a hecho nada para meter al bote al reclutados, engañador,y abusador de la necesidad del mujeres',
#  '@LaydaSansores Estaremos muy atentos y gracias por abrir los ojos de muchos',
#  '@LaydaSansores Pasanos el tuyo en donde llamas pendejo al pendejo de @lopezobrador_  y el de tu sobrino pidiendo sobornos para ti ! Por cierto pregunta seria: si robaste tanto no te alcanzaba para un cirujano plástico certificado ? Quedaste ogta !',
#  '@LaydaSansores Vaya con el apodado Alito, tiene más play list que Bad Bunny.',
#  '@LaydaSansores Yo le pregunto con respeto:¿Por qué solo casa programa solo difunde un extracto de 10 min.minutos., o menos?  Queremos más que eso, porque queremos ver destituido del fuero a este delincuente de A. Moreno, pregúntele al fiscal de solicitar el desafuero como lo mencionó Noroña.',
#  '@LaydaSansores No le deje ni respirar 👊🏻👊🏻🐆',
#  '@LaydaSansores @lopezobrador_ Puro acarreado 🤣🤣🤣',
#  '@LaydaSansores Que emoción',
#  '@LaydaSansores @lopezobrador_  https://t.co/p5ronvMf3R',
#  '@LaydaSansores Que padre! Esto se está poniendo bueno. Han abierto la posibilidad de escuchar los audios de cualquiera, aguas Layda, Claudia, Martí, Marcelo, Adán, al señor Velasco, a Manuel.  WOW que padre, esperamos escuchar a tooooodos',
#  '@LaydaSansores Y por qué no das a conocer el audio de López… ah! No verdad si son de mismo bando de: corruptos,bandidos, cobardes… son un verdadero !ASCO!',
#  '@LaydaSansores Poco a poquito se la estás metiendo!!! Y no sabe que hacer, ya que el mismo no sabe cuantías corrupciones estuvo cometiendo verdad???',
#  '@LaydaSansores ¡Estaremos list@s! 🍿🍕😳😳😳',
#  '@LaydaSansores Esperemos la respuesta con otro suyo! 😎😂',
#  '@LaydaSansores estaremos pendientes el martes',
#  '@LaydaSansores Ya saquen el pack malditasea.',
#  '@LaydaSansores Bien gobernadora, exhiba a Los doble moral, corruptos y cínicos',
#  '@LaydaSansores Cuídate mucho mi querida gobernadora, eres un mujer muy valiente Layda Sansores 👌👏',
#  '@LaydaSansores Ya paren esta masacre!!!',
#  '@LaydaSansores Al fin vas a sacar algo de los ineptos y ratas de @lopezobrador_ y @JRlopezbeltran #FuckAMLO',
#  '@LaydaSansores 🐀🐀🐀🐀🐀🐀🐀🐀🐀🐀🐀  https://t.co/qSJi3FJHVr',
#  '@LaydaSansores Con palabras de alito: QUE PUTIZA LE ESTÁN ACOMODANDO A alito.',
#  '@LaydaSansores Y los de tu sobrino pidiendo moches???',
#  '@LaydaSansores Excelente 😁 ya quiero que sea martes del jaguar 😉',
#  '@LaydaSansores De lujo Gobernadora.😱😱😱',
#  '@LaydaSansores Lo más patético es que todos están de focas aplaudidoras como si fuera un talk show de Laura de América, en lugar de pedir que los gobernantes se dediquen a trabajar.',
#  '@LaydaSansores Y ahora donde se va a ir a quejar #Alitocachondo @alitomorenoc  Seguramente a Marte,por que ya en la Tierra nadie lo pelo.😂🤣 #Packalito #AudioDeAlito',
#  '@LaydaSansores Esta Sra luego de no hacer nada en A Obregón se dedica a publicar videos de 5ta acerca de politiquillos botoxeados iguales a ella desde Campeche en lugar de hacer algo de provecho. Una vergüenza.',
#  '@LaydaSansores Puro succiona pitos ve esa mierda de programa...',
#  '@LaydaSansores 👏👏👏👏👏',
#  '@LaydaSansores Estaremos atentos 👍🏼🎉💥',
#  '@LaydaSansores @Eve3LM Gobernadora el pueblo de mexico esta contigo...y sigue exibiendo a esta bola de corruptos.. y no sueltes a este PADROTE DEL VANDALITO HASTA QUE LO LLEVES PRESO.. ?',
#  '@LaydaSansores Más carnita para deshebrar , a ver qué dice ahora el gigolo de malitomoreno',
#  '@LaydaSansores YA PONGANSE  A TRABAJAR , PURO CHISME  Y  CAMPAÑA SE LA  HAN  LLEVADO .  EL  SELLO  DE  LA  4 T.  CHISMEAR,DIFAMAR,CALUMNIAR  Y  HUEVONEAR',
#  '@LaydaSansores Ayyyyyy 😩 ya quiero que sea martes @alitomorenoc',
#  '@LaydaSansores Dele con todo mi gober',
#  '@LaydaSansores @neter33 No me lo pierdo!!!  https://t.co/qLgxQ0rVo0',
#  '@LaydaSansores  https://t.co/4E2LV9nE7p',
#  '@LaydaSansores @lopezobrador_ Si no está solo tiene mucho cuatrero para ayudarle a robar y tu con la experiencia que tienes',
#  '@LaydaSansores Arre 🤣🤣',
# ...
#  '@LaydaSansores @lopezobrador_ Querida La-ida, eres caga-da. Hija del negro Sansores.',
#  '@LaydaSansores @lopezobrador_ Así o más preparado el video jajaja',
#  '@LaydaSansores @lopezobrador_ Este señor y sus cuentos chinos!',
#  '@LaydaSansores @lopezobrador_  https://t.co/SQxfANhZeX',
#  '@LaydaSansores @lopezobrador_ Así es, no estás solo, estás rodeado de mucho p3ndejo.',
#  '@LaydaSansores Ponte a trabajar Momia huevona y explica lo del rata de tu sobrino, y devuelve todo lo gastado en botox con dinero del erario. Y ya acepta tu edad y no andes de ridícula  https://t.co/QoiRI07xo8',
#  '@LaydaSansores @lopezobrador_ No presidente no está sólo,   está rodeado e teiboleras, narcos, mercenarios, voceros pndejos, etarras, asesinos etc etc etc NO SE SIENTA SOLO!!',
#  '@LaydaSansores @Gerts100 @Tu_IMSS @IMSSBIENESTAR Gracias mi Gobernadora 👍  https://t.co/dJuWziePuG',
#  '@LaydaSansores @lopezobrador_ Trompuda lambiscona , ! querido presidente ) eres más falsa y CORRUPTA de lo que pareces , tu chico habla por ti , cínica 👎🤬💩',
#  '@LaydaSansores preocúpate por tus bronquitas, aborto de Chukie, después ejecutas succión en zona púbica de tu vgt hediondo',
#  '@LaydaSansores No está solo. Esta mal acompañado.',
#  '@LaydaSansores @lopezobrador_ ¿ya oyó el audio el presidente donde le tiras mierda? ahaajajjjaa',
#  '@LaydaSansores @lopezobrador_ Ridícula',
#  '@LaydaSansores @lopezobrador_ Jajajaja ni para 50 acarreados alcanzo el presupuesto',
#  '@LaydaSansores @lopezobrador_ No está solo el macuspano magnánimo santísimo. Esta rodeado de infelices, estúpidos, ladrones, corruptos y malditos. Cómo el.',
#  '@LaydaSansores Excelente familias campechanas, acudan, serà inolvidable',
#  '@LaydaSansores @lopezobrador_ Mentiroso',
#  '@LaydaSansores @lopezobrador_ Desquiciaron el orden de esa calle, qué barbaridad!!!',
#  '@LaydaSansores @lopezobrador_ Estás como @lopezobrador_ en la #Mañanera pidiendo desmontar la Estatua de la Libertad; pero (metafóricamente hablando) de frente te doblas.  Claro al menos q el audio sea falso donde está el apoyo.',
#  '@LaydaSansores @lopezobrador_ Así es ,lo rodea una bola de corruptos ,cínicos ,estafadores e ignorantes como usted .',
#  '@LaydaSansores @lopezobrador_  https://t.co/RLFXu6mlD8',
#  '@LaydaSansores @lopezobrador_ No está solo, el corrupto mayor está rodeado de corruptos, incluyendote. RIDÍCULA.',
#  '@LaydaSansores @lopezobrador_ Es correcto no está solo, está rodeado de narcotraficantes, violadores, rateros, putridos',
#  '@LaydaSansores @RenatoSalesmx   fiscal es vergonzoso prestarse a los circos mediáticos! Eso es caer muy muy bajo.',
#  '@LaydaSansores @lopezobrador_ Será la 🐈 bajo la luvia🌧y maullara por siempre miau😹😹😹',
#  '@LaydaSansores @lopezobrador_ RIDÍCULA! No va a estar solo, porque usted será su compañera cuando vayan a la cárcel por todo lo que han robado; solo es cuestión de tiempo! CORRUPTA!',
#  '@LaydaSansores @lopezobrador_ Loco si pero solo no!!!!!!!😂🤣😂🤣😂🤣😂🤣😂🤣  https://t.co/T3AmOJ0H2k',
#  '@LaydaSansores @lopezobrador_ No sabes lo que es congruencia',
#  '@LaydaSansores @lopezobrador_  https://t.co/BOsF6yYhDm',
#  '@LaydaSansores El próximo Martes un capitulo mas de Alito el mALITO.  https://t.co/ngp1UzPXN2',
#  '@LaydaSansores @lopezobrador_ Jajaja 🤣😃🤣',
#  '@LaydaSansores @AlcaldiaAO Toda una priísta que le sabe al populismo.',
#  '@LaydaSansores @lopezobrador_ Jajaja ahora querido pero en el audio decias otra cosa.',
#  '@LaydaSansores @lopezobrador_ Y el mentecato?',
#  '@LaydaSansores @lopezobrador_ Eso sí no está solo lo acompañan miles de hambreados ladrones webones bestias analfabetas burros cerdos marranos cochino y etc. Claro no está solo todos sol la misma corruptela línea 12 aeropuerto,balneario perdón dos bocas,salud,trabajo,ches rateros mierdas',
#  '@LaydaSansores @lopezobrador_ Pero con tu tipo de política?? Hubiera pasado la información a los que deben actuar e investigar para llegar a un proceso legal y no exhibir a nadie como un circo, tendrías más éxito y te hubieras visto mejor',
#  '@LaydaSansores @lopezobrador_  https://t.co/XzxSf0BDnA',
#  '@LaydaSansores @lopezobrador_ Ya no es el mentecato? Jajajajaja',
#  '@LaydaSansores @lopezobrador_ 😂😂😂😂  https://t.co/jfpTpxz3pp',
#  '@LaydaSansores @lopezobrador_  https://t.co/LpAsBndGk6',
#  '@LaydaSansores @lopezobrador_ Un orgullo estar con Obrador 😃',
#  '@LaydaSansores @lopezobrador_ Está Pío, Felipa, Martinazo corruptazo, el bodoque de la CORRUPCIÓN, los trivagos, y muchos López más  https://t.co/4jnGrN2pTu',
#  '@LaydaSansores @lopezobrador_ Ahora resulta que es muy querido después de que le dijiste mentecato!! 🤣🤣🤣',
#  '@LaydaSansores @lopezobrador_ disculpe, que la asignación de calificativos como fifís, conservadores, neoliberales, aspiracionistas, chayoteros, seminaturistas, corrupos (sin pruebas),, etc. no son expresiones DISCRIMINATORIAS Y RACISTAS?',
#  '@LaydaSansores @lopezobrador_ Lo dice una persona sin escrúpulos, que amenaza, que atenta contra las familias, que provoca desunión… así creo que si se quedará solo, cuado ya no les sirva para sus fines… ademas del hartazgo de la gente con tanta pendejada.',
#  '@LaydaSansores @lopezobrador_ ¡Claro! ¡No está solo! Está rodeado de infames,  delincuentes y corruptos.',
#  '@LaydaSansores @lopezobrador_ O que la chingad#,  primero le dices que es un arrogante y después le dices que no está solo. Que gacho es no tener dignidad y vivir arrastrándote. Hasta a Salinas le hacías guagüis.',
#  '@LaydaSansores @lopezobrador_ Qué hipócrita la novia de de Chucky',
#  '@LaydaSansores @lopezobrador_ Jijijiji!!! Me salió del alma!  https://t.co/2CDBWFrvfw',
#  '@LaydaSansores @lopezobrador_ Está rodeado de corruptos, cínicos, estafadores',
#  '@LaydaSansores @lopezobrador_  https://t.co/lPaXeuNfND',
#  '@LaydaSansores @lopezobrador_ Mi viejecito predicador y mentecato.  😊',
#  '@LaydaSansores @lopezobrador_ Ya sabemos que no esta solo. Está acompañado de cientos de ladrones y delincuentes como tú, y otros millones de cuerpos sin alma que buscan que alguien les dé un plato de lentejas porque no se sienten capaces producir por ellos mismos.',
#  '@LaydaSansores @lopezobrador_ Jajaja 😅😅 y valla que la cirugía de labios 👌👌😅😂😂😂',
#  '@LaydaSansores @lopezobrador_ No te la va a perdonar.',
#  '@LaydaSansores @lopezobrador_ Das risa @LaydaSansores',
#  '@LaydaSansores @lopezobrador_ Esta rodeado de mentecatos. O séase TONDEJOS.',
#  '@LaydaSansores @lopezobrador_ Claro que no! Está rodeado de puro p3nd3j0',
#  '@LaydaSansores @lopezobrador_ Estás en lo cierto no está sólo le siguen, mediocres, personas con conflictos existenciales, los "políticos" corruptos, los que nunca aceptan que sólo tienen lo que merecen, los que no tienen moral, malandros, los que culpan a todos por sus conductas Etc Etc hay una lista larga  https://t.co/wgEVppDTxs',
#  '@LaydaSansores @lopezobrador_ pinche populista y cual transformación?? son políticos como cualquiera de los que tanto critican..que ha transformado?? ya acabo con  la corrupcion? ya hay seguridad? ya tenemoss mejor ecoonomia? mas salud?? se gasta el dinero en puras obras balines¡¡¡',
#  '@LaydaSansores @lopezobrador_ Corrupta y cínica',
#  '@LaydaSansores @lopezobrador_ 🤮🤮🤮🤮🤮',
#  '@LaydaSansores @lopezobrador_ Jajajajajajajajajajajaja paleros.',
#  '@LaydaSansores @lopezobrador_ CORRUPTA!!!',
#  '@LaydaSansores @lopezobrador_ Y luego tú  https://t.co/JgI1PTCuhP',
#  '@LaydaSansores @lopezobrador_ Layda, la gobernadora flamante que dejó la alcaldía Álvaro Obregón sin un centavo. A redactado la personalidad de López Obrador como jamás nadie antes. Y con todo y eso la hicieron gobernadora en complicidad con el crimen, coacción del voto, cargadas, acarreos, una joya.  https://t.co/QwZTfq7ASv',
#  '@LaydaSansores @lopezobrador_ Cuanta razon tiene Layda  no esta solo lo acompaña una banda criminal llamada morena, que con todo cinismo solapa a sus corruptos. BARTLET SCHERER GERTZ EBRAD MARIO IRMA ERENDIRA PIO MARTIN FELIPA BARTLET Jr JOSE RAMON SALGADO MACEDONIO SALMERON  LA PROPIA LAYDA La lista es larga  https://t.co/6NvyXMiZ9W',
#  '@LaydaSansores @lopezobrador_ Claro, el cabrón que cada mañana separa a malos y buenos a conveniencia…',
#  '@LaydaSansores @lopezobrador_ Pura corrupción',
#  '@LaydaSansores @lopezobrador_ Jajajaja antes o después de insultarlo? Con esos amigos para q quiere "conservadores"en su equipo. Que triste lo q estos moreNarcos,hacen por dinero y poder! 🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮🤮 Todos una bola de corruptos, degenerados,tramposos,desleales.',
#  '@LaydaSansores @lopezobrador_ Sácale audios que es lo único que haces bien, porque Gobernar nada de nada',
#  '@LaydaSansores @lopezobrador_ Ya aclaraste tu audio donde básicamente le dices que es un pndejo ?',
#  '@LaydaSansores Jajaja si fue a hacer pero el ridículo!!!  con solo ver las caras de los demás y los ademanes se ve como se burlan de México que pecado estamos pagando',
#  '@LaydaSansores @lopezobrador_ Vieja hipócrita!',
#  '@LaydaSansores Dan asco solo de verlos la anciana lyn may que sigue robando y el ojos de sapo asqueroso',
#  '@LaydaSansores @lopezobrador_ Cálmese ridícula',
#  '@LaydaSansores @lopezobrador_ Lo acompaña toda una banda de asquerosos, delincuentes, misóginos, pederastas y -claro- Narcos La destrucción del país, sin embargo, es responsabilidad total de #LopezBasuraPresidencial Los demás parásitos, como @LaydaSansores son meros cómplices #LigaDeGuerreros',
#  '@LaydaSansores @lopezobrador_ Opinó doña botox',
#  '@LaydaSansores @lopezobrador_ Si cómo no, ere s una vulgar y corriente',
#  '@LaydaSansores @lopezobrador_ No estás solo, tienes los sobres de efectivo',
#  '@LaydaSansores @lopezobrador_ No, está acompañado de puro pendejo. Para muestra, usted.',
#  '@LaydaSansores @lopezobrador_ Esta rodeado de corruptos e Ineptos. Solo que ya es insostenible su gobierno por los malos resultados.',
#  '@LaydaSansores @lopezobrador_ Estas rodeado de puro pendejo',
#  '@LaydaSansores @lopezobrador_ Claro que no @LaydaSansores está rodeado de fanáticos, corruptos y del CO..',
#  '@LaydaSansores @lopezobrador_ Ya tanta droga por la cirugía le está afectando al cerebro @UniNoticias @proceso',
#  '@LaydaSansores @lopezobrador_ A que costo!!!',
#  '@LaydaSansores @lopezobrador_ Claro que no esta solo, está rodeado por una bola de HDSRPM como tú y muchos morenarcotraficantes rateros, corruptos, sátrapas, vulgares, corrientes, además de bien p1nch3s feos como tú. De verte, dan ganas de vomitar, viej@ grotesc@.',
#  '@LaydaSansores @lopezobrador_ Es el mantecato?',
#  '@LaydaSansores @lopezobrador_ ¿Todo tu gremio de teiboleras de tugurio de 4a lo acompaña?',
#  '@LaydaSansores @lopezobrador_ Lo ponen como héroe no mamar! Es un viejo con ideas antiguas, resentido, y que odia a todo mundo.',
#  '@LaydaSansores Aquí hablaras del corrupto de tu sobrino y el dinero que pide desde la subsecretaría?  O de lo involucrada que estás en los asaltos a las plataformas de PEMEX?  O solo harás lo que te encargo el Presidente?',
#  '@LaydaSansores @lopezobrador_ Eso le dijiste a tu estilista, y mira lo qué pasó !!!',
#  '@LaydaSansores @lopezobrador_ Está rodeado de gandallas e ineptos',
#  '@LaydaSansores @lopezobrador_ Este video está producido. Por lo tanto la porra es arreglada. Bola de imbéciles. Ni un triste video pueden hacer bien.',
#  '@LaydaSansores @lopezobrador_  https://t.co/8eakcQaxiZ',
#  '@LaydaSansores @lopezobrador_ 🙄 ya no es mentecato?',
#  '@LaydaSansores @lopezobrador_ Ni la rosa de Guadalupe tiene esas actuaciones.',
#  '@LaydaSansores @lopezobrador_ Ya deja el inyectarte el dinero que te robas en esos labios; corrupta, salúdame a tu sobrino',
#  '@LaydaSansores @lopezobrador_ ¿Y por qué lo tienes que decir?',
#  '@LaydaSansores @lopezobrador_ No está solo ! Está rodeado puro abyecto conformista y resentido!',
#  '@LaydaSansores @lopezobrador_ No está solo,  está loco.',
#  '@LaydaSansores @lopezobrador_ No mms',
#  '@LaydaSansores @lopezobrador_ Señora boca de riñón, su salameria da asco, como su cara',
#  '@LaydaSansores @lopezobrador_ Mientras dure el puesto, que por cierto no es eterno. Después ya se vera…..',
#  '@LaydaSansores @lopezobrador_ Tengo una duda... ¿Cómo está eso lo del mantecato? Es para una tarea...',
#  '@LaydaSansores @lopezobrador_ No está solo esta rodeado de una bola de focas aplaudidoras, compradas.',
#  '@LaydaSansores @lopezobrador_ No no esta sólo la DEA lo apoya!!!   https://t.co/sxd86hzB8c  https://t.co/EanG6qfXNO',
#  '@LaydaSansores @lopezobrador_ Hubiera estado a y para ráyale la madre al wey porque presidente no es',
#  '@LaydaSansores @lopezobrador_ Oiga gobernadora, tengo una duda, sus labios ¿son bucales o vaginales? 🤔',
#  '@LaydaSansores @lopezobrador_ Pues claro que no está solo, todos ustedes corruptos igual que él lo apoyan',
#  '@LaydaSansores @lopezobrador_ Claro que ni está solo! Nunca escuchó el monólogo de Facundo Cabral sobre los pendejos?  “son peligrosos porque al ser mayoría eligen hasta al Presidente....!!!!”.',
#  '@LaydaSansores @lopezobrador_ Querido López eres un mequetrefe,palabras de Layda la taquera',
#  '@LaydaSansores @lopezobrador_ Los mexicanos que votaron con los pies, son leales a SU familia, no a MX, su gobierno y menos a AMLO . Igual que los japoneses en la 2a Guerra, cuando finalmente los dejaron ir a pelear, fueron a defender su modo de vida y nación: EE.UU.; No esperen lealtad a MX en un conflicto.',
#  '@LaydaSansores @lopezobrador_ Lo sabemos, esta rodeado de puro naco, inepto y vulgar',
#  '@LaydaSansores @lopezobrador_ estoy confundido en los audios no decías eso',
#  '@LaydaSansores @lopezobrador_ No mms.. Con este tipo de amigos que hablan mal de uno es mejor es quedarse solo.. #LaVerdaderaLayda #MorenaCuevaDeDelincuentes  https://t.co/nrHwctu1er',
#  '@LaydaSansores @lopezobrador_ Efectivamente, tiene muchos lameSuelas.',
#  '@LaydaSansores @lopezobrador_  https://t.co/JQ5Zq15YIZ',
#  '@LaydaSansores @lopezobrador_  https://t.co/3tY5nykdl7',
#  '@LaydaSansores @lopezobrador_  https://t.co/hBZEAybu3U',
#  '@LaydaSansores @lopezobrador_  https://t.co/KCs7uxsgBh',
#  '@LaydaSansores @lopezobrador_ Ridícula.',
#  '@LaydaSansores @lopezobrador_ No estas solo esta la VIVORA SANSORES',
#  '@LaydaSansores @lopezobrador_ Está rodeado de arrastrados salameros',
#  '@LaydaSansores @lopezobrador_ En la cárcel, tampoco estará solo, te aseguro que tú le harás compañía, miserable!!!',
#  '@LaydaSansores @lopezobrador_ Tú tampoco serás presidenta, besos  ramera,',
#  '@LaydaSansores @lopezobrador_ Claro que no está  sólo está rodeado de puro Pejendejo y acarreado.',
#  '@LaydaSansores @lopezobrador_  https://t.co/aD0hfBxeDT',
#  '@LaydaSansores @lopezobrador_ Hay como 16 millones de Pendejos con él',
#  '@LaydaSansores @lopezobrador_ Sí Mentecato!!! No estás solo!!! #laydanorespetaalpresidente',
#  '@LaydaSansores @lopezobrador_ Jajaja inche cara de guante de beis, primero le dices mentecato, tranza, terco e ignorante y ahora le dices que no esta solo? Bueno si te creo tu y otros corruptos mas son de su misma colonia de ratas.',
#  '@LaydaSansores @Tu_IMSS @IMSSBIENESTAR Tan bonito Campeche ! Están en buenas manos 😉  https://t.co/8ywt8QDAvQ',
#  '@LaydaSansores @lopezobrador_ No está solo, está rodeado de ratas 🐀',
#  '@LaydaSansores @lopezobrador_ Pobre acomplejado q tuvo q llevar acarreados a EEUU por q si no se siente apaludido se deprime. En manos de quien está México',
#  '@LaydaSansores @lopezobrador_ solo el aifa',
#  '@LaydaSansores @lopezobrador_ 🐭🐷🐭🐷🐷🐭🐷🐭🐷🐭🐭',
#  '@LaydaSansores @lopezobrador_ Así mérito le decías a Fox verdad Hipócrita',
#  '@LaydaSansores @lopezobrador_ Lo acompañan agentes de la DEA doña gatillera',
#  '@LaydaSansores @lopezobrador_ Querida lame zuelas, no tiene vergüenza, jamas seremos como Cuba o Venezuela.',
#  '@LaydaSansores @lopezobrador_ Pero porsupuesto que no está solo. Está rodeado DE PUROS LENTEJOS ARRASTRADOS, LAME 🥚🥚 . Cómo usted... Comprenderá.  https://t.co/ieb680qODP',
#  '@LaydaSansores @lopezobrador_ Como era eso de mentecato ???',
#  '@LaydaSansores @lopezobrador_ Obvio no, se rodea de puro pendej0',
#  ...]

# %%
def encode(df):
    data = df.tweet.to_numpy()
    print("Encoding the corpus. This might take a while")
    embeddings = []
    for sentence in data:
        corpus_embeddings = tokenizer.encode(sentence)
        corpus_embeddings = corpus_embeddings / np.linalg.norm(corpus_embeddings,keepdims=True)
        embeddings.append(corpus_embeddings)
        
    return embeddings

# %%
mujeres_embeddings = encode(mujeres)
# Out:
# Encoding the corpus. This might take a while

# %%
hombres_embeddings = encode(hombres)
# Out:
# Encoding the corpus. This might take a while

# %%
datos_encoded = pd.DataFrame([mujeres_embeddings,hombres_embeddings]).T
datos_encoded
# Out:
#                                                        0  \
# 0      [9.200662022541436e-05, 0.022265602094550276, ...
# 1      [4.781730206567746e-05, 0.011571787099893946, ...
# 2      [0.00011344798253902856, 0.027454411774444912,...
# 3      [0.00010210152798898534, 0.02470856977333445, ...
# 4      [6.582413644159152e-05, 0.015929441018865148, ...
# ...                                                  ...
# 37957  [3.7389289487638875e-05, 0.009048208056008608,...
# 37958  [4.1000463572505524e-05, 0.009922112184546337,...
# 37959  [3.6477210693255496e-05, 0.008827484987767831,...
# 37960  [2.8663598269438686e-05, 0.006936590781204162,...
# 37961  [4.8156732418512786e-05, 0.011653929245280093,...
#
#                                                        1
# 0      [7.827947739841682e-05, 0.01894363353041687, 0...
# 1      [2.8872282299460586e-05, 0.006987092316469462,...
# 2      [2.949848419911238e-05, 0.007138633176185196, ...
# 3      [7.657220605912408e-05, 0.018530473866308027, ...
# 4      [6.370191282126117e-05, 0.015415862902745204, ...
# ...                                                  ...
# 37957  [4.8649710248037387e-05, 0.011773229880025047,...
# 37958  [7.455806198140986e-05, 0.018043050999501188, ...
# 37959  [6.878546554227372e-05, 0.016646082661230237, ...
# 37960  [6.851304842519479e-05, 0.01658015771889714, 0...
# 37961  [4.2879659823802964e-05, 0.010376877677360317,...
#
# [37962 rows x 2 columns]

# %%
datos_encoded.columns = ["Mujeres", "Hombres"]

# %%
datos_encoded.to_csv("embeddings.csv")
